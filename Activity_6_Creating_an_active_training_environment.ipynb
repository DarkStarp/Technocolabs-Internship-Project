# %% [markdown]
# # Activity 6: Creating an active training environment
# In this activity we learn to evaluate our LSTM model and to actively train it with new data.

# %% [markdown]
# ## Load Data

# %%
# %autosave 5

#  Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')

from keras.models import load_model
from keras.callbacks import TensorBoard
from datetime import datetime, timedelta
# Out:
# Autosaving every 5 seconds

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, 'scripts')

from utilities_activity6 import *

# %%
#  Load datasets
train = pd.read_csv('train_dataset.csv')
test = pd.read_csv('test_dataset.csv')

# %%
#  Group data into groups containing seven observations
train_data = create_groups(
    train['close_point_relative_normalization'][2:].values)

test_data = create_groups(
    test['close_point_relative_normalization'][:-3].values)

# %%
#  Reshape the data in the format expected by the LSTM layer
X_train, Y_train = split_lstm_input(train_data)

# %% [markdown]
# ## Re-train Model with TensorBoard

# %%
def train_model(model, X, Y, epochs, version, run_number):
    """Training a model with TensorBoard callback.

    This function names each run of the model
    using the TensorBoard naming conventions.

    Parameters
    ----------
    model: Keras model instance
        Compiled Keras model.

    X, Y: np.array
        Series of observations to be used in
        the training process.

    epochs: int
        The number of epochs to train the
        model for.

    version: int
        Version of the model to run.

    run_number: int
        The number of the run. Used in case
        the same model version is run again.
    """
    model_name = f'bitcoin_lstm_v{version}_run_{run_number}'
    tensorboard = TensorBoard(log_dir=f'./logs/{model_name}')

    #  TASK:
    #  Modify the `fit` method to include a TensorBoard callback.
    #
    model_history = model.fit(
        x=X, y=Y,
        batch_size=1, epochs=epochs,
        shuffle=False)

    return model_history

# %%
#  Load previously trained network
model = load_model('bitcoin_lstm_v0.h5')

# %%
#  Retrain network
model_history = train_model(model=model,
                            X=X_train, Y=Y_train,
                            epochs=100,
                            version=0, run_number=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 2/100
# 1/1 [==============================] - 0s 772us/step - loss: 0.0023
# Epoch 3/100
# 1/1 [==============================] - 0s 704us/step - loss: 0.0020
# Epoch 4/100
# 1/1 [==============================] - 0s 778us/step - loss: 0.0018
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 10/100
# 1/1 [==============================] - 0s 948us/step - loss: 0.0010
# Epoch 11/100
# 1/1 [==============================] - 0s 849us/step - loss: 9.3836e-04
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.5599e-04
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.7978e-04
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0919e-04
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4378e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8318e-04
# Epoch 17/100
# 1/1 [==============================] - 0s 822us/step - loss: 5.2708e-04
# Epoch 18/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7520e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2730e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 875us/step - loss: 3.8314e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4252e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 837us/step - loss: 3.0522e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7106e-04
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3985e-04
# Epoch 25/100
# 1/1 [==============================] - 0s 800us/step - loss: 2.1140e-04
# Epoch 26/100
# 1/1 [==============================] - 0s 948us/step - loss: 1.8554e-04
# Epoch 27/100
# 1/1 [==============================] - 0s 897us/step - loss: 1.6211e-04
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4095e-04
# Epoch 29/100
# 1/1 [==============================] - 0s 774us/step - loss: 1.2189e-04
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0480e-04
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.9544e-05
# Epoch 32/100
# 1/1 [==============================] - 0s 804us/step - loss: 7.5981e-05
# Epoch 33/100
# 1/1 [==============================] - 0s 807us/step - loss: 6.3991e-05
# Epoch 34/100
# 1/1 [==============================] - 0s 847us/step - loss: 5.3456e-05
# Epoch 35/100
# 1/1 [==============================] - 0s 882us/step - loss: 4.4263e-05
# Epoch 36/100
# 1/1 [==============================] - 0s 882us/step - loss: 3.6301e-05
# Epoch 37/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9463e-05
# Epoch 38/100
# 1/1 [==============================] - 0s 971us/step - loss: 2.3647e-05
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8758e-05
# Epoch 40/100
# 1/1 [==============================] - 0s 860us/step - loss: 1.4779e-05
# Epoch 41/100
# 1/1 [==============================] - 0s 928us/step - loss: 1.2132e-05
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2557e-05
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6017e-05
# Epoch 44/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9040e-05
# Epoch 45/100
# 1/1 [==============================] - 0s 858us/step - loss: 1.5086e-05
# Epoch 46/100
# 1/1 [==============================] - 0s 920us/step - loss: 8.8674e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 898us/step - loss: 5.2944e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3175e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2850e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6913e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3940e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3052e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 850us/step - loss: 1.4614e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 967us/step - loss: 1.9286e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 831us/step - loss: 2.9330e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6042e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 848us/step - loss: 6.9002e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 806us/step - loss: 8.4729e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5707e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.9451e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 889us/step - loss: 5.3138e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8986e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0958e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 879us/step - loss: 2.6090e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4736e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5375e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 889us/step - loss: 2.8875e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 946us/step - loss: 3.4468e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3300e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2922e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 868us/step - loss: 6.2778e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6738e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6331e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9331e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 858us/step - loss: 5.2301e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 879us/step - loss: 4.4619e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9951e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 860us/step - loss: 3.6524e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 955us/step - loss: 3.5919e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 896us/step - loss: 3.6494e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 902us/step - loss: 3.9479e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3135e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 893us/step - loss: 4.8482e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 910us/step - loss: 5.2715e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 827us/step - loss: 5.6736e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 997us/step - loss: 5.7197e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6560e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2840e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9697e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5685e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 833us/step - loss: 4.3556e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 849us/step - loss: 4.1647e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 855us/step - loss: 4.1785e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 821us/step - loss: 4.2214e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4392e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 865us/step - loss: 4.6300e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 903us/step - loss: 4.9275e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 898us/step - loss: 5.0855e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2641e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 942us/step - loss: 5.2190e-06

# %% [markdown]
# ## Evaluate LSTM Model

# %%
#  Combine training and testing datasets
combined_set = np.concatenate((train_data, test_data), axis=1)

# %%
#  Evaluate model at each week for the test set
evaluated_weeks = []
for i in range(0, test_data.shape[1]):
    input_series = combined_set[0:, i:i + 77]

    X_test = input_series[0:, :-1].reshape(1, input_series.shape[1] - 1, 7)
    Y_test = input_series[0:, -1:][0]

    result = model.evaluate(x=X_test, y=Y_test, verbose=0)
    evaluated_weeks.append(result)

# %%
#  Plot MSE for all evaluated weeks
ax = pd.Series(evaluated_weeks).plot(drawstyle="steps-post",
                                     figsize=(14, 4),
                                     color='#2c3e50',
                                     grid=True,
                                     title='Mean Squared Error (MSE) for Test Data')

ax.set_xticks(range(0, len(evaluated_weeks)))
ax.set_xlabel("Predicted Week")
ax.set_ylabel("MSE")
plt.show()

# %% [markdown]
# ## Interpreting Model Results

# %% [markdown]
# ### Make Predictions

# %%
#  Make predictions for each of the 19 weeks
#  in the test set
predicted_weeks = []
for i in range(0, test_data.shape[1]):
    input_series = combined_set[0:, i:i + 76]
    predicted_weeks.append(model.predict(input_series))

# %%
#  Flatten `predicted_weeks` to get a list
#  of predictions for each day in the 19 weeks
predicted_days = []
for week in predicted_weeks:
    predicted_days += list(week[0])

# %%
#  Create list of dates associated with predictions
last_day = datetime.strptime(train['date'].max(), '%Y-%m-%d')
list_of_days = []
for days in range(1, len(predicted_days) + 1):
    D = (last_day + timedelta(days=days)).strftime('%Y-%m-%d')
    list_of_days.append(D)

# %%
#  Create dataframe with predicted values
predicted = pd.DataFrame({
    'date': list_of_days,
    'close_point_relative_normalization': predicted_days
})
predicted.head()
# Out:
#          date  close_point_relative_normalization
# 0  2017-06-25                           -0.001222
# 1  2017-06-26                            0.018707
# 2  2017-06-27                            0.069612
# 3  2017-06-28                            0.052898
# 4  2017-06-29                            0.065696

# %%
#  Convert `date` variable to datetime
predicted['date'] = predicted['date'].apply(
    lambda x: datetime.strptime(x, '%Y-%m-%d'))

test['date'] = test['date'].apply(
    lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
def plot_two_series(A, B, variable, title):
    """Plot two series using the same `date` index. 
    
    Parameters
    ----------
    A, B: pd.DataFrame
        Dataframe with a `date` key and a variable
        passed in the `variable` parameter. Parameter A
        represents the "Observed" series and B the "Predicted"
        series. These will be labelled respectively. 
    
    variable: str
        Variable to use in plot.
    
    title: str
        Plot title.
    """
    plt.figure(figsize=(14, 4))
    plt.xlabel('Observed and predicted')

    ax1 = A.set_index('date')[variable].plot(
        color='#d35400', grid=True, label='Observed', title=title)

    ax2 = B.set_index('date')[variable].plot(
        color='grey', grid=True, label='Predicted')
    
    ax1.set_xlabel("Predicted Week")
    ax1.set_ylabel("Predicted Values")

    plt.legend()
    plt.show()

# %%
#  Plot predicted normalized prices
#  against actual normalized prices
plot_two_series(A=test[:-3],
                B=predicted,
                variable='close_point_relative_normalization',
                title='Normalized Predictions per Week')

# %% [markdown]
# ### De-normalize Predictions

# %%
#  Add variable `iso_week` by stripping the Year and Week from `date`
predicted['iso_week'] = predicted['date'].apply(
    lambda x: x.strftime('%Y-%U'))

# %%
def denormalize(reference, series,
                normalized_variable='close_point_relative_normalization',
                denormalized_variable='close'):
    """Denormalize the values for a given series.

    Parameters
    ----------
    reference: pd.DataFrame
        DataFrame to use as reference. This dataframe
        contains both a week index and the USD price
        reference that we are interested on.

    series: pd.DataFrame
        DataFrame with the predicted series. The
        DataFrame must have the same columns as the
        `reference` dataset.

    normalized_variable: str, default 'close_point_relative_normalization'
        Variable to use in normalization.

    denormalized_variable: str, default `close`
        Variable to use in de-normalization.

    Returns
    -------
    A modified DataFrame with the new variable provided
    in `denormalized_variable` parameter.
    """
    week_values = reference[reference['iso_week'] == series['iso_week'].values[0]]
    last_value = week_values[denormalized_variable].values[0]
    series[denormalized_variable] = last_value * (series[normalized_variable] + 1)

    return series

# %%
#  Denormalize predictions
predicted_close = predicted.groupby('iso_week').apply(
    lambda x: denormalize(test[:-3], x))

# %%
#  Plot denormalized predictions and observed closing prices in test set
plot_two_series(A=test[:-3],
                B=predicted_close,
                variable='close',
                title='De-normalized Predictions per Week')

# %% [markdown]
# ### Calculate RMSE and MAPE

# %%
A = test[:-3]['close_point_relative_normalization']
B = predicted_close['close_point_relative_normalization']

print(f'Normalized RMSE: {rmse(A, B):.2f}')
# Out:
# Normalized RMSE: 0.10

# %%
A = test[:-3]['close']
B = predicted_close['close']

print(f'De-normalized RMSE: {rmse(A, B):.2f}')
print(f'De-normalized MAPE: {mape(A, B):.2f}')
# Out:
# De-normalized RMSE: 354.12
# De-normalized MAPE: 6.84
